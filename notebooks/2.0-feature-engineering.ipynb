# %% [markdown]
# # Feature Engineering
#
# Created for Urban Heat Island Project

# %%
import pandas as pdimport numpy as npimport matplotlib.pyplot as pltimport seaborn as sns# Set up plotting styleplt.style.use('seaborn')%matplotlib inline
